# %%
def func1():
  print("Welcome to useer defined functions !!! you are in function body")

func1()
print("you are in main body")
# Out:
# Welcome to useer defined functions !!! you are in function body
# you are in main body

# %%
# funciton sum getting value and retuning value
def sum(a,b):
  print("in function")
  c=a+b
  d=a-b
  return c,d


# main code
a=int(input("enter any number"))
b=int(input("enter any number"))
t=sum(a,b)
print(type(t))
print("sum of 2 numbers",t[0])
print("sub of 2 numbers",t[1])
print("in main")
# Out:
# enter any number23
# enter any number33
# in function
# <class 'tuple'>
# sum of 2 numbers 56
# sub of 2 numbers -10
# in main

# %%
# funciton getting value but not retuning value
def even_odd(n):
  if n % 2==0:
    print(n," It is an Even Number")
  else:
    print(n, "is an odd number")


# main
print("in main")
even_odd(23)
# Out:
# in main
# 23 is an odd number

# %%
# funciton getting value but not retuning value
def even_odd(n):
  if n % 2==0:
    return(" It is an Even Number")
  else:
     return (" this is an odd number")

# main
print("in main")
even_odd(23)
# Out:
# in main
# ' this is an odd number'

# %%
# function not getting any thing but retuning something

def Func1():
  return "welcome to python class"


# main
s=func1()
print("in main")
print(s)
# Out:
# in main
# welcome to python class

# %% [markdown]
# Create a functions for
# 1. squaing a number
# 2. cube a number

# %%
def square_number(num):
  """Squares a number."""
  return num ** 2

def cube_number(num):
  """Cubes a number."""
  return num ** 3

num = int(input("Enter the number"))
print("Square of ",num, "is =", square_number(num))
print("cube of ",num , "is ", cube_number(num))
# Out:
# Enter the number3
# Square of  3 is = 9
# cube of  3 is  27

# %%
def greet_ms(a,name="Mohan"):
  print("welcoome to python session ", a, name)

#main
greet_ms(2,"Rakhee")
greet_ms(2)
# Out:
# welcoome to python session  2 Rakhee
# welcoome to python session  2 Mohan

# %%
def greet_ms(name,msg):
  print(name,msg)

# main

greet_ms( msg="How r u?", name="Rakhee")
# Out:
# Rakhee How r u?

# %%
t=[1,2,3,4,5]
a,*b,c = t
print(a,b,c)
# Out:
# 1 [2, 3, 4] 5

# %%
# Global and Local Scope of variables in python
def add_diff(x,y):
  z=x+y
  z1=x-y
  global m
  m=m+10
  print("the value of m in function",m)
  return z, z1
def func1():
  print("this is func1 ", m)
def main():
  x=9
  y=10
  m=0
  a,b=add_diff(x,y)
  print("sum ", t[0],type(t[0]))
  print("Difference ", t[1])
  m=m+30
  m=m*2
  print("the value of m in main",m)
  m=23
  print("the value of m in main",m)
  func1()
main()
# Out:
# the value of m in function 43
# sum  19 <class 'int'>
# Difference  -1
# the value of m in main 60
# the value of m in main 23
# this is func1  43

# %%
def f1():
  print(m3)
def f2():
  global m3
  m3=0
  m3=m3+10
  print(m3)

f1()
f2()
# Out:
# 10
# 10

# %% [markdown]
# Create a menu driven code for calculations depending on inputed symbol
# + - "addition of 2 number"
# - - "substraction of 2 number"
# * - "multiplication"
# / - "division"
# //- "floor division"
# ** - "power"
#
#
# menu driven code for calculation of area of different geometric shapes
# square
# rectangle
# tringle - isoseles, right angle
# circle
